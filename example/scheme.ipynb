# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

left = np.array(["KHB18", "JHL18", "XLG22", "LGX17", "RS21", "TFC19", "YW19","OURS"])
height = np.array([0.432715, 0.448581,0.432715, 0.948164, 0.911523,103.662887,0.911523,0.437384])
plt.bar(left, height)
plt.show()
